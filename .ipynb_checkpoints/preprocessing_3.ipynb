# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Extracting features of 2018 movies data from Wikipedia

# %%
link = 'https://en.wikipedia.org/wiki/List_of_American_films_of_2018'
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                      Momentum Pictures / GFM Films
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
df2.head()
# Out:
#   Opening  Opening.1                       Title  \
# 0   APRIL          6               A Quiet Place
# 1   APRIL          6                    Blockers
# 2   APRIL          6  You Were Never Really Here
# 3   APRIL          6              Chappaquiddick
# 4   APRIL          6                      Pandas
#
#                                   Production company  \
# 0  Paramount Pictures / Platinum Dunes / Sunday N...
# 1  Universal Pictures / Good Universe / Point Gre...
# 2                                     Amazon Studios
# 3                              Entertainment Studios
# 4                       Warner Bros. Pictures / IMAX
#
#                                        Cast and crew  Ref.
# 0  John Krasinski (director/screenplay); Scott Be...  [76]
# 1  Kay Cannon (director); Eben Russell, Jon Hurwi...  [77]
# 2  Lynne Ramsay (director/screenplay); Joaquin Ph...  [78]
# 3  John Curran (director); Taylor Allen, Andrew L...  [79]
# ...

# %%
df3.head()
# Out:
#   Opening  Opening.1                                  Title  \
# 0    JULY          4                        The First Purge
# 1    JULY          6                   Ant-Man and the Wasp
# 2    JULY          6                    Sorry to Bother You
# 3    JULY          6                                Whitney
# 4    JULY         13  Hotel Transylvania 3: Summer Vacation
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / P...
# 1  Marvel Studios / Walt Disney Studios Motion Pi...
# 2                                 Annapurna Pictures
# 3                     Roadside Attractions / Miramax
# 4  Columbia Pictures / Sony Pictures Animation / MRC
#
#                                        Cast and crew   Ref.
# 0  Gerard McMurray (director); James DeMonaco (sc...  [135]
# 1  Peyton Reed (director); Chris McKenna, Erik So...  [136]
# 2  Boots Riley (director/screenplay); Lakeith Sta...  [137]
# ...

# %%
df4.head()
# Out:
#    Opening  Opening.1                            Title  \
# 0  OCTOBER          2                 Power of the Air
# 1  OCTOBER          5                            Venom
# 2  OCTOBER          5                   A Star Is Born
# 3  OCTOBER          5  The Great Buster: A Celebration
# 4  OCTOBER         10                 The Happy Prince
#
#                          Production company  \
# 0                       Five & Two Pictures
# 1  Columbia Pictures / Marvel Entertainment
# 2                     Warner Bros. Pictures
# 3                         Cohen Media Group
# 4                    Sony Pictures Classics
#
#                                        Cast and crew   Ref.
# 0  Dave Christiano (director/screenplay); Nichola...  [204]
# 1  Ruben Fleischer (director); Jeff Pinkner, Scot...  [205]
# 2  Bradley Cooper (director/screenplay); Eric Rot...  [206]
# 3                       Peter Bogdanovich (director)  [207]
# 4  Rupert Everett (director/screenplay); Rupert E...  [208]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df.head()
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\2054277875.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                      Momentum Pictures / GFM Films
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# ...

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '8861664dc84c9b818a4b1040a1cb1fe5'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 270  DECEMBER         25             Holmes & Watson
# 271  DECEMBER         25                        Vice
# 272  DECEMBER         25         On the Basis of Sex
# 273  DECEMBER         25                   Destroyer
# 274  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# 3                                 Samuel Goldwyn Films
# ...

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018['Cast and crew']
# Out:
# 0      Adam Robitel (director); Leigh Whannell (scree...
# 1      Lauren Wolkstein (director); Christopher Radcl...
# 2      Simon West (director); Duncan Falconer, Warren...
# 3      Warwick Thornton (director); David Tranter, St...
# 4      Jaume Collet-Serra (director); Byron Willinger...
#                              ...
# 270    Etan Cohen (director/screenplay); Will Ferrell...
# 271    Adam McKay (director/screenplay); Christian Ba...
# 272    Mimi Leder (director); Daniel Stiepleman (scre...
# 273    Karyn Kusama (director); Phil Hay, Matt Manfre...
# 274    David Slade (director); Charlie Brooker (scree...
# Name: Cast and crew, Length: 275, dtype: object

# %%
df_2018['Cast and crew'][0]
# Out:
# 'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'

# %%
x = "'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'"
if 'director' in x:
    print(x.split(" (director);")[0])
    print((x.split("screenplay); ")[-1]).split(", ")[0])
# Out:
# 'Adam Robitel
# Lin Shaye

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018['director_name'][0]
# Out:
# 'Adam Robitel'

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\2517195254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 270             Holmes & Watson
# 271                        Vice
# 272         On the Basis of Sex
# 273                   Destroyer
# 274  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 270  Etan Cohen (director/screenplay); Will Ferrell...
# 271  Adam McKay (director/screenplay); Christian Ba...
# 272  Mimi Leder (director); Daniel Stiepleman (scre...
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 270          Etan Cohen     Will Ferrell          John C. Reilly
# 271          Adam McKay   Christian Bale               Amy Adams
# 272          Mimi Leder   Felicity Jones            Armie Hammer
# 273        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 274         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# ...

# %% [markdown]
# ### Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1_2019 = pd.read_html(link, header=0)[2]
df2_2019 = pd.read_html(link, header=0)[3]
df3_2019 = pd.read_html(link, header=0)[4]
df4_2019 = pd.read_html(link, header=0)[5]

# %%
df = df1_2019.append(df2_2019.append(df3_2019.append(df4_2019,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\534431954.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1_2019.append(df2_2019.append(df3_2019.append(df4_2019,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                       Momentum Pictures / GFM Films
# ...

# %%
df1['genres'] = df1['Title'].map(lambda x: get_genre(str(x)))

# %%
df1['genres']
# Out:
# 0              Horror Mystery Thriller
# 1                       Thriller Drama
# 2                      Action Thriller
# 3         Western Crime Thriller Drama
# 4              Action Thriller Mystery
#                     ...
# 69    Science Fiction Adventure Action
# 70                            Thriller
# 71                               Drama
# 72        Mystery Crime Drama Thriller
# 73                               Drama
# Name: genres, Length: 74, dtype: object

# %%
df_2019 = df1[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                                   Title  \
# 0               Insidious: The Last Key
# 1                      The Strange Ones
# 2                              Stratton
# 3                         Sweet Country
# 4                          The Commuter
# ..                                  ...
# 69                     Ready Player One
# 70               Tyler Perry's Acrimony
# 71  God's Not Dead: A Light in Darkness
# 72                               Gemini
# 73                  The Last Movie Star
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Lauren Wolkstein (director); Christopher Radcl...
# 2   Simon West (director); Duncan Falconer, Warren...
# 3   Warwick Thornton (director); David Tranter, St...
# 4   Jaume Collet-Serra (director); Byron Willinger...
# ..                                                ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...
# ...

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
df_2019['director_name']
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\3911787317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# 0           Adam Robitel
# 1       Lauren Wolkstein
# 2             Simon West
# 3       Warwick Thornton
# 4     Jaume Collet-Serra
#              ...
# 69      Steven Spielberg
# 70           Tyler Perry
# 71         Michael Mason
# 72            Aaron Katz
# 73           Adam Rifkin
# Name: director_name, Length: 74, dtype: object

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
df_2019['actor_1_name']
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\6080429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# 0             Lin Shaye
# 1         Alex Pettyfer
# 2        Dominic Cooper
# 3           Bryan Brown
# 4           Liam Neeson
#             ...
# 69         Tye Sheridan
# 70     Taraji P. Henson
# 71    David A. R. White
# 72           Lola Kirke
# 73        Burt Reynolds
# Name: actor_1_name, Length: 74, dtype: object

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
df_2019['actor_2_name']
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\868052934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# 0              Angus Sampson
# 1     James Freedson-Jackson
# 2             Austin Stowell
# 3                  Sam Neill
# 4               Vera Farmiga
#                ...
# 69              Olivia Cooke
# 70                Lyriq Bent
# 71              John Corbett
# 72               Zoë Kravitz
# 73              Ariel Winter
# Name: actor_2_name, Length: 74, dtype: object

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
df_2019['actor_3_name']
# Out:
# 0     Leigh Whannell
# 1      Emily Althaus
# 2         Gemma Chan
# 3                NaN
# 4     Patrick Wilson
#            ...
# 69    Ben Mendelsohn
# 70      Tika Sumpter
# 71      Shane Harper
# 72         Greta Lee
# 73        Clark Duke
# Name: actor_3_name, Length: 74, dtype: object

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
df_2019
# Out:
#                             movie_title  \
# 0               Insidious: The Last Key
# 1                      The Strange Ones
# 2                              Stratton
# 3                         Sweet Country
# 4                          The Commuter
# ..                                  ...
# 69                     Ready Player One
# 70               Tyler Perry's Acrimony
# 71  God's Not Dead: A Light in Darkness
# 72                               Gemini
# 73                  The Last Movie Star
#
#                                         Cast and crew  \
# 0   Adam Robitel (director); Leigh Whannell (scree...
# 1   Lauren Wolkstein (director); Christopher Radcl...
# 2   Simon West (director); Duncan Falconer, Warren...
# 3   Warwick Thornton (director); David Tranter, St...
# 4   Jaume Collet-Serra (director); Byron Willinger...
# ..                                                ...
# 69  Steven Spielberg (director); Ernest Cline, Zak...
# ...

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#          director_name       actor_1_name            actor_2_name  \
# 0         Adam Robitel          Lin Shaye           Angus Sampson
# 1     Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2           Simon West     Dominic Cooper          Austin Stowell
# 3     Warwick Thornton        Bryan Brown               Sam Neill
# 4   Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                 ...                ...                     ...
# 69    Steven Spielberg       Tye Sheridan            Olivia Cooke
# 70         Tyler Perry   Taraji P. Henson              Lyriq Bent
# 71       Michael Mason  David A. R. White            John Corbett
# 72          Aaron Katz         Lola Kirke             Zoë Kravitz
# 73         Adam Rifkin      Burt Reynolds            Ariel Winter
#
#       actor_3_name                            genres  \
# 0   Leigh Whannell           Horror Mystery Thriller
# 1    Emily Althaus                    Thriller Drama
# ...

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
my_df
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\3800406928.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df18.append(new_df19,ignore_index=True)
#           director_name       actor_1_name            actor_2_name  \
# 0          Adam Robitel          Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2            Simon West     Dominic Cooper          Austin Stowell
# 3      Warwick Thornton        Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                  ...                ...                     ...
# 344    Steven Spielberg       Tye Sheridan            Olivia Cooke
# 345         Tyler Perry   Taraji P. Henson              Lyriq Bent
# 346       Michael Mason  David A. R. White            John Corbett
# ...

# %%
old_df = pd.read_csv('../Ada Boost/new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\mkmt724\AppData\Local\Temp\ipykernel_17904\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#           director_name       actor_1_name      actor_2_name  \
# 0         James Cameron        CCH Pounder  Joel David Moore
# 1        Gore Verbinski        Johnny Depp     Orlando Bloom
# 2            Sam Mendes    Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan          Tom Hardy    Christian Bale
# 4           Doug Walker        Doug Walker        Rob Walker
# ...                 ...                ...               ...
# 5708   Steven Spielberg       Tye Sheridan      Olivia Cooke
# 5709        Tyler Perry   Taraji P. Henson        Lyriq Bent
# 5710      Michael Mason  David A. R. White      John Corbett
# 5711         Aaron Katz         Lola Kirke       Zoë Kravitz
# 5712        Adam Rifkin      Burt Reynolds      Ariel Winter
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport          Action Adventure Fantasy
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df
# Out:
#           director_name       actor_1_name      actor_2_name  \
# 0         James Cameron        CCH Pounder  Joel David Moore
# 1        Gore Verbinski        Johnny Depp     Orlando Bloom
# 2            Sam Mendes    Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan          Tom Hardy    Christian Bale
# 4           Doug Walker        Doug Walker        Rob Walker
# ...                 ...                ...               ...
# 5708   Steven Spielberg       Tye Sheridan      Olivia Cooke
# 5709        Tyler Perry   Taraji P. Henson        Lyriq Bent
# 5710      Michael Mason  David A. R. White      John Corbett
# 5711         Aaron Katz         Lola Kirke       Zoë Kravitz
# 5712        Adam Rifkin      Burt Reynolds      Ariel Winter
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport          Action Adventure Fantasy
# ...

# %%
final_df.to_csv('../Ada Boost/final_data.csv',index=False)

# %%
final_df.to_csv('../Recomendation_datsets/final_data.csv',index=False)
